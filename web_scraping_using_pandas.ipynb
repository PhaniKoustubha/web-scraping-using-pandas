# %% [markdown]
# <a href="https://colab.research.google.com/github/PhaniKoustubha/web-scraping-using-pandas/blob/main/web_scraping_using_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Develop a Simple Python Script**

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage you want to scrape
url = 'https://en.wikipedia.org/wiki/Virat_Kohli'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(response.text, 'html.parser')

# Find specific elements using BeautifulSoup methods
# For example, to extract all links on the page:
links = soup.find_all('a')

# Print the extracted links
for link in links:
    print(link.get('href'))
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Virat+Kohli
# /w/index.php?title=Special:UserLogin&returnto=Virat+Kohli
# /w/index.php?title=Special:CreateAccount&returnto=Virat+Kohli
# /w/index.php?title=Special:UserLogin&returnto=Virat+Kohli
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life
# #Youth_and_domestic_career
# #Delhi
# #India_Under-19
# #International_career
# #2008–2009:_Debut_and_maiden_stint
# ...

# %%
# Send GET request
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse HTML content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract links
    links = soup.find_all('a')
    for link in links:
        href = link.get('href')
        if href:
            print(href)
else:
    print('Failed to retrieve the webpage. Status code:', response.status_code)
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Virat+Kohli
# /w/index.php?title=Special:UserLogin&returnto=Virat+Kohli
# /w/index.php?title=Special:CreateAccount&returnto=Virat+Kohli
# /w/index.php?title=Special:UserLogin&returnto=Virat+Kohli
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life
# #Youth_and_domestic_career
# #Delhi
# #India_Under-19
# #International_career
# #2008–2009:_Debut_and_maiden_stint
# ...

# %% [markdown]
# **Extract relevant information such as text, links, or images from web pages.**

# %%
# Extract text from paragraphs
paragraphs = soup.find_all('p')
for paragraph in paragraphs:
    print(paragraph.text)
# Out:
# Indian International cricketer
#
# Recognition
#
# Player of the year
#
# Test Player of the year
#
# ODI Player of the year
#
# ...

# %%
# Extract links
links = soup.find_all('a')
for link in links:
    print(link.get('href'))
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Virat+Kohli
# /w/index.php?title=Special:UserLogin&returnto=Virat+Kohli
# /w/index.php?title=Special:CreateAccount&returnto=Virat+Kohli
# /w/index.php?title=Special:UserLogin&returnto=Virat+Kohli
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life
# #Youth_and_domestic_career
# #Delhi
# #India_Under-19
# #International_career
# #2008–2009:_Debut_and_maiden_stint
# ...

# %%
# Extract image URLs
images = soup.find_all('img')
for image in images:
    print(image.get('src'))
# Out:
# /static/images/icons/wikipedia.png
# /static/images/mobile/copyright/wikipedia-wordmark-en.svg
# /static/images/mobile/copyright/wikipedia-tagline-en.svg
# //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/e/ef/Virat_Kohli_during_the_India_vs_Aus_4th_Test_match_at_Narendra_Modi_Stadium_on_09_March_2023.jpg/220px-Virat_Kohli_during_the_India_vs_Aus_4th_Test_match_at_Narendra_Modi_Stadium_on_09_March_2023.jpg
# //upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/23px-Flag_of_India.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Virat_Kohli_Signature.svg/100px-Virat_Kohli_Signature.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/1/15/Virat_Kohli_portrait.jpg/100px-Virat_Kohli_portrait.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Virat_Kohli_Batting.jpg/235px-Virat_Kohli_Batting.jpg
# ...
